# %% [markdown]
# ## Séries Temporáis

# %% [markdown]
# https://www.youtube.com/watch?v=28dG0gyXz80

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import yfinance as yf

# %%
tickets = {
    'ticket0' : yf.Ticker('GGBR4.SA'),
    'ticket1' : yf.Ticker('GGBR3.SA'),
    'ticket2' : yf.Ticker('VALE3.SA'),
    'ticket3' : yf.Ticker('USIM5.SA'),
    'ticket4' : yf.Ticker('CSNA3.SA')}

# %%
from matplotlib.transforms import interval_contains


for ticket in tickets.values():
    print(ticket)
# Out:
# yfinance.Ticker object <GGBR4.SA>
# yfinance.Ticker object <GGBR3.SA>
# yfinance.Ticker object <VALE3.SA>
# yfinance.Ticker object <USIM5.SA>
# yfinance.Ticker object <CSNA3.SA>

# %%
df
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2019-10-31 00:00:00-03:00  11.232710  14.552030  11.191323  14.071929
# 2019-11-12 00:00:00-03:00        NaN        NaN        NaN        NaN
# 2019-11-30 00:00:00-03:00  13.909677  16.723149  13.801785  16.598660
# 2019-12-31 00:00:00-03:00  16.598658  18.706688  16.266685  16.640154
# 2020-01-31 00:00:00-03:00  16.640156  18.499207  13.403418  14.050766
# 2020-03-01 00:00:00-03:00  14.308043  15.386957   6.772253   8.340826
# 2020-03-02 00:00:00-03:00        NaN        NaN        NaN        NaN
# 2020-04-01 00:00:00-03:00   8.205979  10.642000   7.615681   9.760709
# 2020-05-01 00:00:00-03:00   9.760710  11.564861   9.078957  11.165787
# 2020-06-01 00:00:00-03:00  11.431836  13.643377  10.916365  13.310815
# 2020-07-01 00:00:00-03:00  13.177787  15.065080  12.654001  14.508038
# 2020-08-01 00:00:00-03:00  14.707579  16.960690  14.167165  15.871548
# ...

# %%
df.tail()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2022-08-01 00:00:00-03:00  23.950353  25.525651  22.345884  22.676502
# 2022-08-16 00:00:00-03:00        NaN        NaN        NaN        NaN
# 2022-09-01 00:00:00-03:00  23.340000  25.299999  22.480000  24.440001
# 2022-10-01 00:00:00-03:00  25.070000  27.219999  24.740000  26.980000
# 2022-10-24 00:00:00-03:00   0.000000   0.000000   0.000000  26.860001
#
#                                 Volume  Dividends  Stock Splits
# Date
# 2022-08-01 00:00:00-03:00  291376800.0       0.00             0
# 2022-08-16 00:00:00-03:00          NaN       0.71             0
# 2022-09-01 00:00:00-03:00  288581100.0       0.00             0
# 2022-10-01 00:00:00-03:00  146123100.0       0.00             0
# 2022-10-24 00:00:00-03:00          0.0       0.00             0
